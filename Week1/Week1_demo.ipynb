# %% [markdown]
# # Yahoo Stock Major
# https://tw.stock.yahoo.com/d/s/major_2451.html

# %% [markdown]
# https://github.com/datasci-info/PyCrawler101-201510/blob/master/Week1/Ex1_YahooStockMajor_try.ipynb

# %%
from pycrawler101.week1 import yahooStockMajor

# %%
yahooStockMajor.getData(2330)
# Out:
#          date  stock_id broker  long short
# 0  2015-10-02      2330  台灣摩根士  4993  1590
# 1  2015-10-02      2330   摩根大通  3043   586
# 2  2015-10-02      2330  新加坡商瑞  2624   229
# 3  2015-10-02      2330   富邦證券  1195   118
# 4  2015-10-02      2330   群益金鼎  1013   105
# 5  2015-10-02      2330   日盛證券   469    72
# 6  2015-10-02      2330  香港上海匯   687   319
# 7  2015-10-02      2330   花旗環球   376   110
# 8  2015-10-02      2330   康和證券   260    26
# 9  2015-10-02      2330   國票證券   212    25
# 10 2015-10-02      2330   凱基證券   693   509
# 11 2015-10-02      2330     臺銀   233    67
# 12 2015-10-02      2330   兆豐證券   155    25
# 13 2015-10-02      2330  台灣東方匯   593   530
# 14 2015-10-02      2330  港商法國興    61     1
# 15 2015-10-02      2330  港商麥格里    38  6093
# 16 2015-10-02      2330   國泰證券    33  2317
# 17 2015-10-02      2330   美商高盛  1072  2310
# 18 2015-10-02      2330   瑞士信貸  2612  3444
# 19 2015-10-02      2330   港商野村     0   496
# 20 2015-10-02      2330   法銀巴黎     0   492
# ...

# %% [markdown]
# # PCHOME Search
# http://ecshweb.pchome.com.tw/search/v3.3/?q=sony

# %% [markdown]
# https://github.com/datasci-info/PyCrawler101-201510/blob/master/Week1/Ex2_pchomeSearch_try.ipynb

# %%
from pycrawler101.week1 import pchomeSearch

# %%
pchomeSearch.getData(q="sony").head()
# Out:
#                  Id author brand  cateId                          describe  \
# 0  DYAD26-A90066KI0               DYAD26   ◤送32G卡 ◢SONY Xperia Z3+ (E6553)
# 1  DYAD2O-A9006J87V               DYAD2O   現貨到★我可以0.03秒撼凍世界★SONY Xperia Z5
# 2  DYAI04-A9006E0VE               DYAI04  SONY SmartWatch 2 SW2 - 防水觸控藍芽手錶
# 3  DYAD27-A9006G1IM               DYAD2L          ▼送皮套+16G卡↘Sony Xperia M5
# 4  DGAD01-A90067X1Y               DGAD01      新上市★32G副電組SONY RX100 M4(公司貨)
#
#    isPick                     name  \
# 0       0  SONY Xperia Z3+ (E6553)
# 1       0           SONY Xperia Z5
# 2       0            SONY SW2 藍牙手錶
# 3       0           Sony Xperia M5
# 4       0  SONY數位相機 RX100 M4 (公司貨)
#
#                                                 picB  \
# 0  /pic/v1/data/item/201510/D/Y/A/D/2/6/DYAD26-A9...
# 1  /pic/v1/data/item/201510/D/Y/A/D/2/O/DYAD2O-A9...
# 2  /pic/v1/data/item/201509/D/Y/A/I/0/4/DYAI04-A9...
# 3  /pic/v1/data/item/201509/D/Y/A/D/2/7/DYAD27-A9...
# ...

# %% [markdown]
# # MOPS Stock IDs
# http://mops.twse.com.tw/mops/web/t51sb01

# %% [markdown]
# https://github.com/datasci-info/PyCrawler101-201510/blob/master/Week1/Ex3_mopsStockIDs_try.ipynb

# %%
from pycrawler101.week1 import mopsStockIDs

# %%
mopsStockIDs.getData("sii").head()
# Out:
# 0  公司代號        公司名稱                      住址  營利事業統一編號  董事長  總經理  發言人   發言人職稱  \
# 1  1101  台灣水泥股份有限公司           台北市中山北路2段113號  11913502  辜成允  辜成允  黃健強  資深副總經理
# 2  1102  亞洲水泥股份有限公司  台北市大安區敦化南路2段207號30、31樓  03244509  徐旭東  李坤炎  周維崑    副總經理
# 3  1103  嘉新水泥股份有限公司            台北市中山北路2段96號  11892801  張剛綸  祁士鉅  王立心  執行副總經理
# 4  1104  環球水泥股份有限公司        台北市南京東路二段125號10樓  07568009  侯博義  侯博義  詹志鴻      協理
# 5  1108  幸福水泥股份有限公司           台北市松江路237號15樓  40601248  陳兩傳  陳兩傳  溫秀菊   財務部經理
#
# 0 代理發言人           總機電話                        ...                          \
# 1   蔡立文  (02)2531-7099                        ...
# 2   吳玲綾   02-2733-8000                        ...
# 3   余曉芸   (02)25515211                        ...
# 4   楊宗仁    02-25077801                        ...
# 5   陳一誠       25092188                        ...
#
# 0                過戶地址      簽證會計師事務所 簽證會計師1 簽證會計師2          英文簡稱  \
# 1      台北市重慶南路一段83號5樓  勤業眾信聯合會計師事務所    翁雅玲    吳美慧           TCC
# ...

# %%
mopsStockIDs.getData("otc").head()
# Out:
# 0  公司代號          公司名稱                                    住址  營利事業統一編號  董事長  \
# 1  1256    鮮活控股股份有限公司  P.O. BOX 10338,GRAND CAYMAN KY1-1003  37759808  黃國晃
# 2  1258  其祥生物科技控股有限公司                        台北市中山區松江路51號8樓  53028230  王其祥
# 3  1259  安心食品服務股份有限公司                     台北市中山區松江路156-1號8樓  23928945  黃茂雄
# 4  1264    德麥食品股份有限公司                         新北市五股區五權五路31號  23420497  林雪嬌
# 5  1333   恩得利工業股份有限公司                         新北市新莊區化成路203號  84584513  林義雄
#
# 0  總經理  發言人 發言人職稱 代理發言人           總機電話  \
# 1  黃國晃  吳明憲    董事   吳金海   512-57515501
# 2  王建山  王建山   總經理   游志宗  (02)2518-4933
# 3  高順興  施啟寅    協理   何頎胤  (02)2567-5001
# 4  吳文欽  邱俊榮  財務經理   賴素瑛  (02)2298-1347
# 5  林有欽  林有欽   總經理   黃悌愷  (02)8993-1760
#
# 0                        ...                                            過戶地址  \
# 1                        ...                                  台北市忠孝東路二段95號1樓
# 2                        ...                                  臺北巿敦化南路2段97號B2
# ...

# %% [markdown]
# # POST GUESTBOOK
# http://apt-bonbon-93413.appspot.com/

# %% [markdown]
# https://github.com/datasci-info/PyCrawler101-201510/blob/master/Week1/Ex4_postMessage_try.ipynb

# %%
from pycrawler101.week1 import postGuestbook

# %%
postGuestbook.postMessage()

# %%
postGuestbook.postMessage("Hello! Python!")

# %% [markdown]
# # Pandas
# http://pandas.pydata.org/pandas-docs/stable/remote_data.html

# %%
In [1]: import pandas.io.data as web

In [2]: import datetime

In [3]: start = datetime.datetime(2010, 1, 1)

In [4]: end = datetime.datetime(2013, 1, 27)

In [5]: f = web.DataReader("F", 'yahoo', start, end)

In [6]: f.ix['2010-01-04']
# Out:
# Open               10.170000
# High               10.280000
# Low                10.050000
# Close              10.280000
# Volume       60855800.000000
# Adj Close           9.244219
# Name: 2010-01-04 00:00:00, dtype: float64
