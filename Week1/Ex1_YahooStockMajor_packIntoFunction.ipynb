# %%
import requests
import re
from datetime import datetime
import pandas as pd
import numpy as np

# %%
class NotFindDataError(Exception):
    def __init__(self, url):
        self.url

# %%
def yahooStockMajor(stock_id):
    url = "https://tw.stock.yahoo.com/d/s/major_{stock_id}.html".format(stock_id=stock_id)
    res = requests.get(url)
    res.raise_for_status()
    
    tables = pd.read_html(res.text)
    filtered_tables = filter(lambda xx:xx.shape[1] == 8, tables)
    if len(filtered_tables) == 0:
        raise NotFindDataError(url)
    else:
        df = filter(lambda xx:xx.shape[1] == 8, tables)[0]
    
    df = pd.DataFrame(np.r_[df.values[1:,0:3], df.values[1:,4:7]],columns=["broker","long","short"])
    
    pat = re.compile(u"([0-9]+ /[0-9]+ /[0-9]+)")
    date = map(int,pat.findall(res.text)[0].split("/"))
    date[0] = 1911 + date[0]
    date = datetime(*date)
    
    df["stock_id"] = stock_id
    df["date"] = date
    
    df = df[["date","stock_id", "broker","long","short"]]
    
    return df

# %%
yahooStockMajor(2330)
# Out:
#          date  stock_id broker  long short
# 0  2015-10-19      2330   瑞士信貸  6075    52
# 1  2015-10-19      2330     美林  2697   681
# 2  2015-10-19      2330   摩根大通  3460  1934
# 3  2015-10-19      2330  台灣東方匯  1498    60
# 4  2015-10-19      2330  港商德意志  1428    25
# 5  2015-10-19      2330   美商高盛  1246   480
# 6  2015-10-19      2330  港商麥格里   887   449
# 7  2015-10-19      2330   港商野村   381     9
# 8  2015-10-19      2330   大眾證券   160    22
# 9  2015-10-19      2330   合庫證券   144    26
# 10 2015-10-19      2330  新加坡商瑞  2345  2232
# 11 2015-10-19      2330  香港上海匯   225   167
# 12 2015-10-19      2330   富隆證券    59    10
# 13 2015-10-19      2330   康和證券    95    58
# 14 2015-10-19      2330     日茂    21     2
# 15 2015-10-19      2330   國泰證券    22  4584
# 16 2015-10-19      2330  台灣摩根士  1946  3557
# 17 2015-10-19      2330   大和國泰     0  1539
# 18 2015-10-19      2330   花旗環球    43  1532
# 19 2015-10-19      2330     元富   172  1472
# 20 2015-10-19      2330   日盛證券   112  1267
# 21 2015-10-19      2330   群益金鼎   211  1316
# 22 2015-10-19      2330  台灣巴克萊   182   900
# 23 2015-10-19      2330   凱基證券   529   728
# 24 2015-10-19      2330   華南永昌    88   202
# 25 2015-10-19      2330     統一    72   174
# 26 2015-10-19      2330   富邦證券   425   491
# 27 2015-10-19      2330   台灣企銀    11    69
# 28 2015-10-19      2330   元大證券   565   608
# 29 2015-10-19      2330   國票證券    54    91

# %%
yahooStockMajor(1542)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-6-5e0672b7147e> in <module>()
# ----> 1 yahooStockMajor(1542)
#
# <ipython-input-4-a9d9c176aa8b> in yahooStockMajor(stock_id)
#       2     url = "https://tw.stock.yahoo.com/d/s/major_{stock_id}.html".format(stock_id=stock_id)
#       3     res = requests.get(url)
# ----> 4     res.raise_for_status()
#       5
#       6     tables = pd.read_html(res.text)
#
# /home/c3h3/.pyenv/versions/anaconda-2.3.0/lib/python2.7/site-packages/requests/models.pyc in raise_for_status(self)
#     835
#     836         if http_error_msg:
# --> 837             raise HTTPError(http_error_msg, response=self)
#     838
#     839     def close(self):
#
# HTTPError: 404 Client Error: Not Found for url: https://tw.stock.yahoo.com/d/s/major_1542.html
