# %%
import requests

# %%
from pyquery import PyQuery

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36',
    "Referer":"http://www.104.com.tw/"
}

# %%
s = requests.Session()

# %%
s.headers.update(headers)

# %%
s.headers
# Out:
# {'Connection': 'keep-alive', 'Referer': 'http://www.104.com.tw/', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36'}

# %%
res1 = s.get("http://www.104.com.tw/")

# %%
from IPython.core.display import HTML

# %%
HTML(res1.text)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Language"content="zh-tw">
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=8,IE=9">
# <title>104人力銀行 - 工作機會數領先，找工作、找人才必用的人力銀行
# </title>
# <link rel="search" href="/opensearch.xml"  type="application/opensearchdescription+xml" title="104人力銀行工作搜尋" />
# <meta name="description" content="104是最多求職者使用的人力銀行，提供找工作、找人才之專業便利的求職求才服務，包括查詢工作、刊登履歷、薪資行情、職涯測驗、手機找工作等，並榮獲國際ISO 27001資安認證，更重視求職者個資安全。- 104人力銀行，不只找工作，為你找方向！不只找人才，為你找夥伴！">
# <meta name="keywords" content="104,工作,人才,找工作,找人才,求職,求才,全職,兼職,工讀,打工,履歷,自傳,就業,薪資行情,找人,徵人,徵才,人力資源,104人力銀行,人力銀行,派遣,獵才,家教,外包,接案,教育,進修,證照,job,career,resume,hr">
# <meta property="fb:admins"content="100000426555526"/>
# <meta property="fb:app_id"content="114319901946493"/>
# <meta property="og:title" content="104人力銀行 - 工作機會數領先，找工作、找人才必用的人力銀行"/>
# ...

# %%
s.cookies.get_dict()
# Out:
# {}

# %%
res2 = s.post("http://login.104.com.tw/login.cfm?frombar=jbbar_login",{"return_url":"http://www.104.com.tw/"})

# %%
s.cookies.get_dict()
# Out:
# {'COOKIE_VERIFY': '%7Bts%20%272015%2D10%2D15%2012%3A15%3A29%27%7D'}

# %%
res2.headers
# Out:
# {'content-length': '7810', 'content-encoding': 'gzip', 'set-cookie': 'COOKIE_VERIFY=%7Bts%20%272015%2D10%2D15%2012%3A15%3A29%27%7D; Path=/, SSOLOGON_SOURCE=""; Expires=Thu, 01-Jan-1970 00:00:10 GMT; Path=/', 'vary': 'Accept-Encoding,User-Agent', 'keep-alive': 'timeout=5, max=100', 'server': '', 'connection': 'Keep-Alive', 'date': 'Thu, 15 Oct 2015 04:15:29 GMT', 'content-type': 'text/html;charset=UTF-8'}

# %%
s.cookies.set("SSOLOGON_SOURCE","")
# Out:
# Cookie(version=0, name='SSOLOGON_SOURCE', value='', port=None, port_specified=False, domain='', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False)

# %%
s.cookies.get_dict()
# Out:
# {'COOKIE_VERIFY': '%7Bts%20%272015%2D10%2D15%2012%3A15%3A29%27%7D',
#  'SSOLOGON_SOURCE': ''}

# %%
S = PyQuery(res2.text)

# %%
S("#captInput").outerHtml()
# Out:
# u'<li id="captInput" class="jb-capt">\n\t\t\t\t\t\t<input id="captchaCode" name="captchaCode" type="text" value="" placeholder="\u82f1\u6578\u5b57\u4e0d\u5206\u5927\u5c0f\u5beb" autocomplete="off">\n\t\t\t\t\t\t\n\t\t\t\t\t\t<img id="captLoading" src="http://static.104.com.tw/104main/login/img/ill_loader_24.gif" alt="Loading" style="display: none;">\n\t\t\t\t\t\t<img id="accaptchaimg">\n\t\t\t\t\t\t<input id="changeImg" type="button" value="\u63db\u4e00\u7d44">\n\t\t\t\t\t\t<input type="hidden" id="captchaKey" name="captchaKey" value>\n\t\t\t\t\t\t</li>'
