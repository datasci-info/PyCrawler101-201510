# %% [markdown]
# # Connector

# %%
import requests

# %%
res = requests.get("http://news.cnyes.com/Content/20151017/20151017090126631872610.shtml?c=headline_channel")

# %% [markdown]
# # u' + \x

# %%
res.encoding
# Out:
# 'ISO-8859-1'

# %%
#print res.text

# %%
res.encoding = "utf8"

# %%
#print res.text

# %% [markdown]
# # Parser (XPATH)

# %%
from lxml import etree

# %%
doc = etree.HTML(res.text)

# %%
print doc.xpath("//h1")[0].text
# Out:
# 蔡崇信：全資收購優土將推動進一步合作

# %%
print doc.xpath("//div[@class='info']")[0].text
# Out:
# 鉅亨網新聞中心　(來源：北美新浪)　2015-10-17  09:01

# %%
doc.xpath("//div[@id='newsText']")[0].text
# Out:
# '\r\n\t\t\t\t\t'

# %%
e = doc.xpath("//div[@id='newsText']")[0]

# %%
import lxml.html

# %%
print lxml.html.tostring(e)
# Out:
# <div id="newsText">
# 					<p>&#26032;&#28010;&#31185;&#25216;&#35338; &#21271;&#20140;&#26178;&#38291;10&#26376;16&#26085;&#26202;&#38291;&#28040;&#24687;&#65292;&#38463;&#37324;&#24052;&#24052;&#20170;&#22825;&#23459;&#20296;&#65292;&#23559;&#20197;&#36229;&#36942;45&#20740;&#32654;&#20803;&#30340;&#20729;&#26684;&#25910;&#36092;&#20778;&#37239;&#22303;&#35910;&#12290;&#28040;&#24687;&#23459;&#20296;&#21518;&#65292;&#38463;&#37324;&#24052;&#24052;&#31649;&#29702;&#23652;&#65292;&#21253;&#25324;&#22519;&#34892;&#21103;&#33891;&#20107;&#38263;&#34081;&#23815;&#20449;&#21644;&#39318;&#24109;&#36001;&#21209;&#23448;&#27494;&#34907;&#21443;&#21152;&#20102;&#38651;&#35441;&#26371;&#35696;&#65292;&#22238;&#31572;&#20102;&#20998;&#26512;&#24107;&#25552;&#21839;&#12290;</p>
# <p>&#20197;&#19979;&#28858;&#20998;&#26512;&#24107;&#21839;&#31572;&#29872;&#31680;&#20027;&#35201;&#20839;&#23481;&#65306;</p>
#
# ...

# %%
from IPython.core.display import HTML

# %%
HTML(lxml.html.tostring(e))
# Out:
# <div id="newsText">
# 					<p>&#26032;&#28010;&#31185;&#25216;&#35338; &#21271;&#20140;&#26178;&#38291;10&#26376;16&#26085;&#26202;&#38291;&#28040;&#24687;&#65292;&#38463;&#37324;&#24052;&#24052;&#20170;&#22825;&#23459;&#20296;&#65292;&#23559;&#20197;&#36229;&#36942;45&#20740;&#32654;&#20803;&#30340;&#20729;&#26684;&#25910;&#36092;&#20778;&#37239;&#22303;&#35910;&#12290;&#28040;&#24687;&#23459;&#20296;&#21518;&#65292;&#38463;&#37324;&#24052;&#24052;&#31649;&#29702;&#23652;&#65292;&#21253;&#25324;&#22519;&#34892;&#21103;&#33891;&#20107;&#38263;&#34081;&#23815;&#20449;&#21644;&#39318;&#24109;&#36001;&#21209;&#23448;&#27494;&#34907;&#21443;&#21152;&#20102;&#38651;&#35441;&#26371;&#35696;&#65292;&#22238;&#31572;&#20102;&#20998;&#26512;&#24107;&#25552;&#21839;&#12290;</p>
# <p>&#20197;&#19979;&#28858;&#20998;&#26512;&#24107;&#21839;&#31572;&#29872;&#31680;&#20027;&#35201;&#20839;&#23481;&#65306;</p>
#
# ...

# %%
from HTMLParser import HTMLParser

# %%
parser = HTMLParser()

# %%
parser.unescape(lxml.html.tostring(e))
# Out:
# u'<div id="newsText">\r\n\t\t\t\t\t<p>\u65b0\u6d6a\u79d1\u6280\u8a0a \u5317\u4eac\u6642\u959310\u670816\u65e5\u665a\u9593\u6d88\u606f\uff0c\u963f\u91cc\u5df4\u5df4\u4eca\u5929\u5ba3\u4f48\uff0c\u5c07\u4ee5\u8d85\u904e45\u5104\u7f8e\u5143\u7684\u50f9\u683c\u6536\u8cfc\u512a\u9177\u571f\u8c46\u3002\u6d88\u606f\u5ba3\u4f48\u540e\uff0c\u963f\u91cc\u5df4\u5df4\u7ba1\u7406\u5c64\uff0c\u5305\u62ec\u57f7\u884c\u526f\u8463\u4e8b\u9577\u8521\u5d07\u4fe1\u548c\u9996\u5e2d\u8ca1\u52d9\u5b98\u6b66\u885b\u53c3\u52a0\u4e86\u96fb\u8a71\u6703\u8b70\uff0c\u56de\u7b54\u4e86\u5206\u6790\u5e2b\u63d0\u554f\u3002</p>\r\n<p>\u4ee5\u4e0b\u70ba\u5206\u6790\u5e2b\u554f\u7b54\u74b0\u7bc0\u4e3b\u8981\u5167\u5bb9\uff1a</p>\r\r\n\t\t\t\t\t\r\n\t\t\t\t\t<!--source from http://news.chinayes.com--><div class="adunit" data-adunit="cnyes_news_insideleft_300*250" data-dimensions="300x250"></div>\r\n\t\t\t\t\t\r\n\t\t\t\t\t<p>\u7f8e\u9280\u7f8e\u6797\u5206\u6790\u5e2b\u6881\u5049\u4eae\uff1a\u7b2c\u4e00\u500b\u554f\u984c
# ...

# %%
print parser.unescape(lxml.html.tostring(e))
# Out:
# <div id="newsText">
# 					<p>新浪科技訊 北京時間10月16日晚間消息，阿里巴巴今天宣佈，將以超過45億美元的價格收購優酷土豆。消息宣佈后，阿里巴巴管理層，包括執行副董事長蔡崇信和首席財務官武衛參加了電話會議，回答了分析師提問。</p>
# <p>以下為分析師問答環節主要內容：</p>
#
# 					<!--source from http://news.chinayes.com--><div class="adunit" data-adunit="cnyes_news_insideleft_300*250" data-dimensions="300x250"></div>
#
# 					<p>美銀美林分析師梁偉亮：第一個問題關於這筆收購的時機。你們去年收購了優酷土豆的部分股份，那麼在過去一年中發生了什麼樣的情況，促使你們希望全資收購優酷土豆？第二個問題，你們提到了收購帶來的合力，那麼未來你們將專注於什麼樣的財務和運營指標，以判斷是否成功實現了合力？</p>
# <p>蔡崇信：我們去年5月收購了優酷土豆的部分股份，並與該公司進行了業務合作，具體的合作領域包括廣告，以及某些數據整合。例如，我們試圖匹配淘寶用戶帳號和優酷平台觀的帳號。我們取得了良好的效果。但如果不完全收購該公司，許多合作會有局限。我們希望對資源進行更緊密的整合，團隊之間更緊密的合作，因此我們提出全資收購優酷土豆。</p>
# <p>關於合力的問題，這將包括精準營銷，以及通過媒體數據和電商數據更好地理解我們的用戶群，從而打造更強大的品和服務。這些領域可以生合力。</p>
# <p>摩根士丹利分析師羅伯特·林：我理解優酷土豆的成本主要在於內容、頻寬和主機等，能否量化這筆收購給內容和頻寬成本帶來的節約？第二個問題關於用戶。你們已經對兩家公司掌握的數據進行了匹配，那麼優酷土豆和阿里巴巴的用戶群體有多少的重疊？</p>
# ...

# %%
data = {}

# %%
data["title"] = doc.xpath("//h1")[0].text

# %%
data["info"] = doc.xpath("//div[@class='info']")[0].text

# %%
data["body"] = parser.unescape(lxml.html.tostring(e))

# %%
data
# Out:
# {'body': u'<div id="newsText">\r\n\t\t\t\t\t<p>\u65b0\u6d6a\u79d1\u6280\u8a0a \u5317\u4eac\u6642\u959310\u670816\u65e5\u665a\u9593\u6d88\u606f\uff0c\u963f\u91cc\u5df4\u5df4\u4eca\u5929\u5ba3\u4f48\uff0c\u5c07\u4ee5\u8d85\u904e45\u5104\u7f8e\u5143\u7684\u50f9\u683c\u6536\u8cfc\u512a\u9177\u571f\u8c46\u3002\u6d88\u606f\u5ba3\u4f48\u540e\uff0c\u963f\u91cc\u5df4\u5df4\u7ba1\u7406\u5c64\uff0c\u5305\u62ec\u57f7\u884c\u526f\u8463\u4e8b\u9577\u8521\u5d07\u4fe1\u548c\u9996\u5e2d\u8ca1\u52d9\u5b98\u6b66\u885b\u53c3\u52a0\u4e86\u96fb\u8a71\u6703\u8b70\uff0c\u56de\u7b54\u4e86\u5206\u6790\u5e2b\u63d0\u554f\u3002</p>\r\n<p>\u4ee5\u4e0b\u70ba\u5206\u6790\u5e2b\u554f\u7b54\u74b0\u7bc0\u4e3b\u8981\u5167\u5bb9\uff1a</p>\r\r\n\t\t\t\t\t\r\n\t\t\t\t\t<!--source from http://news.chinayes.com--><div class="adunit" data-adunit="cnyes_news_insideleft_300*250" data-dimensions="300x250"></div>\r\n\t\t\t\t\t\r\n\t\t\t\t\t<p>\u7f8e\u9280\u7f8e\u6797\u5206\u6790\u5e2b\u6881\u5049\u4eae\uff1a\u7b2c\u4e00\u500b\u5
# ...

# %%
import pandas as pd

# %%
pd.DataFrame([data])
# Out:
#                                                 body  \
# 0  <div id="newsText">\r\n\t\t\t\t\t<p>新浪科技訊 北京時間...
#
#                                    info               title
# 0  鉅亨網新聞中心　(來源：北美新浪)　2015-10-17  09:01　  蔡崇信：全資收購優土將推動進一步合作

# %% [markdown]
# # ~~~~~~~~~

# %%
res = requests.get("http://news.cnyes.com/headline_channel/list.shtml")

# %%
res.encoding = "utf8"

# %%
doc = etree.HTML(res.text)

# %%
doc.xpath("//ul[@class='list_1 bd_dbottom']/h2/li/a")
# Out:
# []

# %%
#doc.xpath("//ul[@class='list_1 bd_dbottom']//li/a")

# %%
e = doc.xpath("//ul[@class='list_1 bd_dbottom']//li/a")[0]

# %%
e.attrib["href"]
# Out:
# 'http://news.cnyes.com/Content/20151017/20151017094209838131210.shtml?c=headline_channel'

# %% [markdown]
# # map

# %%
map(lambda e:e.attrib["href"],doc.xpath("//ul[@class='list_1 bd_dbottom']//li/a"))
# Out:
# ['http://news.cnyes.com/Content/20151017/20151017094209838131210.shtml?c=headline_channel',
#  'http://news.cnyes.com/Content/20151017/20151017090126631872610.shtml?c=headline_channel',
#  'http://news.cnyes.com/Content/20151017/20151017090115663911710.shtml?c=headline_channel',
#  'http://news.cnyes.com/Content/20151017/20151017085125381652410.shtml?c=headline_channel',
#  'http://news.cnyes.com/Content/20151017/20151017060341538255610.shtml?c=headline_channel',
#  'http://news.cnyes.com/Content/20151017/20151017053650722126810.shtml?c=headline_channel',
#  'http://news.cnyes.com/Content/20151017/20151017051536970241710.shtml?c=headline_channel',
#  'http://news.cnyes.com/Content/20151017/20151017044943548265210.shtml?c=headline_channel',
#  'http://news.cnyes.com/Content/20151017/20151017042355108415410.shtml?c=headline_channel',
#  'http://news.cnyes.com/Content/20151017/20151017033859322374710.shtml?c=headline_channel',
# ...

# %% [markdown]
# # iterator

# %%
[e.attrib["href"] for e in doc.xpath("//ul[@class='list_1 bd_dbottom']//li/a")]
# Out:
# ['http://news.cnyes.com/Content/20151017/20151017094209838131210.shtml?c=headline_channel',
#  'http://news.cnyes.com/Content/20151017/20151017090126631872610.shtml?c=headline_channel',
#  'http://news.cnyes.com/Content/20151017/20151017090115663911710.shtml?c=headline_channel',
#  'http://news.cnyes.com/Content/20151017/20151017085125381652410.shtml?c=headline_channel',
#  'http://news.cnyes.com/Content/20151017/20151017060341538255610.shtml?c=headline_channel',
#  'http://news.cnyes.com/Content/20151017/20151017053650722126810.shtml?c=headline_channel',
#  'http://news.cnyes.com/Content/20151017/20151017051536970241710.shtml?c=headline_channel',
#  'http://news.cnyes.com/Content/20151017/20151017044943548265210.shtml?c=headline_channel',
#  'http://news.cnyes.com/Content/20151017/20151017042355108415410.shtml?c=headline_channel',
#  'http://news.cnyes.com/Content/20151017/20151017033859322374710.shtml?c=headline_channel',
# ...

# %% [markdown]
# # generator

# %%
g = (e.attrib["href"] for e in doc.xpath("//ul[@class='list_1 bd_dbottom']//li/a"))

# %%
g.next()
# Out:
# 'http://news.cnyes.com/Content/20151017/20151017085125381652410.shtml?c=headline_channel'

# %% [markdown]
# # Yahoo News

# %%
url = "https://tw.news.yahoo.com/%E5%85%A8%E5%9C%8B%E8%BE%B2%E6%9D%91%E9%A0%98%E8%88%AA%E7%8D%8E-%E9%9B%B2%E6%9E%97%E8%A1%A8%E6%8F%9A%E7%8D%B2%E7%8D%8E6%E4%BA%BA-085410532.html"
res = requests.get(url)

# %%
res.encoding
# Out:
# 'UTF-8'

# %%
doc = etree.HTML(res.text)

# %%
print doc.xpath("//h1[@class='headline']")[0].text
# Out:
# 全國農村領航獎 雲林表揚獲獎6人

# %%
print doc.xpath("//span[@class='provider org']")[0].text
# Out:
# 中央社

# %%
print doc.xpath("//div[@id='mediaarticlebody']/div[@class='bd']")[0].text
# Out:
# None

# %% [markdown]
# # Exercise !

# %% [markdown]
# # CSS PATH

# %% [markdown]
# # document.querySelectorAll("h2 > a")

# %% [markdown]
# # JQuery

# %%
from pyquery import PyQuery

# %%
S = PyQuery(res.text)

# %%
print S("h1.headline").text()
# Out:
# 全國農村領航獎 雲林表揚獲獎6人

# %%
print S("div#mediaarticlebody > div.bd").text()
# Out:
# （中央社記者葉子綱雲林縣16日電）農委會舉辦農村領航獎，全國獲獎人30名，雲林縣有6人獲獎，縣長李進勇今天頒發獎座，期勉開創新氣象。 李進勇接見農村領航獎雲林縣獲獎人，稱讚是農村英雄，不僅是雲林人同享的光榮，更是雲林可貴的農村資源。 農村領航獎分為農好物—產業活化、農好青—青年返鄉、農好境—生態保育、農好蘊—文化美學等4大領域。 雲林獲獎6人分別是，古坑樟湖林啟顯（染布）、大埔柳四勇（木材研究）、水林瓊埔蘇嘉益（地瓜）的產業活化；大埤西鎮唐偉仁（帶妻小投入社區）的青年返鄉；麥寮新吉林錦山（紙漿藝術村）、虎尾頂溪蘇坤福（屋頂上的貓）的文化美學。 李進勇表示，除了頒發穀亭畚造型獎座表揚，並安排至日本訪視交流，觀摩學習農村再生、小農自產自銷、自然農法及栽種技術等，再接再厲，創新雲林農業氣象。1041016

# %%
print S("div#mediaarticlebody > div.bd").outerHtml()
# Out:
# <div class="bd"><!-- google_ad_section_start --><p class="first">（中央社記者葉子綱雲林縣16日電）農委會舉辦農村領航獎，全國獲獎人30名，雲林縣有6人獲獎，縣長李進勇今天頒發獎座，期勉開創新氣象。</p><p>    李進勇接見農村領航獎雲林縣獲獎人，稱讚是農村英雄，不僅是雲林人同享的光榮，更是雲林可貴的農村資源。</p><p>    農村領航獎分為農好物—產業活化、農好青—青年返鄉、農好境—生態保育、農好蘊—文化美學等4大領域。</p><p>    雲林獲獎6人分別是，古坑樟湖林啟顯（染布）、大埔柳四勇（木材研究）、水林瓊埔蘇嘉益（地瓜）的產業活化；大埤西鎮唐偉仁（帶妻小投入社區）的青年返鄉；麥寮新吉林錦山（紙漿藝術村）、虎尾頂溪蘇坤福（屋頂上的貓）的文化美學。</p><p>    李進勇表示，除了頒發穀亭畚造型獎座表揚，並安排至日本訪視交流，觀摩學習農村再生、小農自產自銷、自然農法及栽種技術等，再接再厲，創新雲林農業氣象。1041016</p>
# <!-- google_ad_section_end --></div>

# %% [markdown]
#  - class <-> .
#  - id <-> #
#  - / <-> >
#  - // <-> " "

# %%
url = "https://tw.news.yahoo.com/%E5%85%A8%E5%9C%8B%E8%BE%B2%E6%9D%91%E9%A0%98%E8%88%AA%E7%8D%8E-%E9%9B%B2%E6%9E%97%E8%A1%A8%E6%8F%9A%E7%8D%B2%E7%8D%8E6%E4%BA%BA-085410532.html"

# %%
import urllib

# %%
print urllib.unquote(url)
# Out:
# https://tw.news.yahoo.com/全國農村領航獎-雲林表揚獲獎6人-085410532.html

# %%
print urllib.quote(urllib.unquote(url))
# Out:
# https%3A//tw.news.yahoo.com/%E5%85%A8%E5%9C%8B%E8%BE%B2%E6%9D%91%E9%A0%98%E8%88%AA%E7%8D%8E-%E9%9B%B2%E6%9E%97%E8%A1%A8%E6%8F%9A%E7%8D%B2%E7%8D%8E6%E4%BA%BA-085410532.html

# %%
postData = {"commandid" : "SearchStore",
             "city" : u"台北市",
             "town": u"大安區"}

# %%
res = requests.post("http://emap.pcsc.com.tw/EMapSDK.aspx",data=postData)

# %%
res.text[:10]
# Out:
# u'<?xml vers'

# %%
res.text.encode("utf8")[:10]
# Out:
# '<?xml vers'

# %%
doc = etree.fromstring(res.text.encode("utf8"))

# %%
e = doc.xpath("//GeoPosition")[0]

# %%
for c in e.iterchildren():
    print c.tag, c.text
# Out:
# POIID 153319
# POIName 大台
# X 121532614.37826
# Y 25017959.8345753
# Telno (02)23636229
# FaxNo (02)23660784
# Address 台北市大安區羅斯福路3段283巷14弄16號1樓
# isDining Y
# isParking N
# isLavatory N
# isATM Y
# is7WiFi Y
# isIce N
# isHotDog N
# isHealthStations N
# isIceCream N
# isOpenStore N
# isFruit N
# isCityCafe Y
# isUnionPay N
# isOrganic N
# isCorn N
# isMakeup N
# isMuji N
# isMisterDonuts N
# SpecialStore_Kind None
# Store_URL None

# %%
data = map(lambda e:dict([(c.tag,c.text) for c in e.iterchildren()]),  doc.xpath("//GeoPosition"))

# %%
#data

# %% [markdown]
# # requests.Session

# %%
import requests
from pyquery import PyQuery

# %%
s = requests.Session()

# %%
s.headers
# Out:
# {'Connection': 'keep-alive', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'User-Agent': 'python-requests/2.7.0 CPython/2.7.10 Linux/4.2.2-1-ARCH'}

# %%
s.cookies.get_dict()
# Out:
# {}

# %%
headers = {
    "User-Agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36"
}

# %%
s.headers.update(headers)

# %%
s.headers
# Out:
# {'Connection': 'keep-alive', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36'}

# %%
res1 = s.get("http://www.marketwatch.com/newsviewer")

# %%
res1.headers
# Out:
# {'content-length': '52993', 'content-encoding': 'gzip', 'set-cookie': '.ASPXAUTH=; domain=marketwatch.com; expires=Tue, 12-Oct-1999 05:00:00 GMT; path=/; HttpOnly, kayla=g=eb75737b320e445d8a79653f7c3fa0b2; domain=.marketwatch.com; expires=Sat, 17-Oct-2020 03:37:21 GMT; path=/', 'expires': 'Sat, 17 Oct 2015 03:37:22 GMT', 'vary': 'Accept-Encoding', 'x-machine': 'secdedtwebp01', 'server': 'Microsoft-IIS/7.5', 'connection': 'keep-alive', 'x-aspnetmvc-version': '3.0', 'pragma': 'no-cache', 'cache-control': 'max-age=0, no-cache, no-store', 'date': 'Sat, 17 Oct 2015 03:37:22 GMT', 'x-powered-by': 'ASP.NET', 'content-type': 'text/html; charset=utf-8', 'x-aspnet-version': '4.0.30319'}

# %%
s.cookies.get_dict()
# Out:
# {'kayla': 'g=eb75737b320e445d8a79653f7c3fa0b2'}
